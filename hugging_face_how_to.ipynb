# %% [markdown]
# <a href="https://colab.research.google.com/github/matician255/NEURAL-NETWORK-FLASHCARDS/blob/main/hugging_face_how_to.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install -U datasets huggingface_hub
from datasets import load_dataset, disable_caching
from huggingface_hub import login

login()  # Will prompt for token
disable_caching()  # Disable problematic caching

dataset = load_dataset(
    "oscar",
    name="unshuffled_deduplicated_sw",
    split="train",
    token=True,
    trust_remote_code=True
)

# Extract all text entries and save to file
with open("swahili_oscar.txt", "w", encoding="utf-8") as f:
    for example in dataset:
        text = example["text"]
        # Optional: Add basic cleaning
        text = text.replace("<br />", "\n")  # Remove HTML line breaks
        f.write(text + "\n")  # Add newline between documents

print(f"Saved {len(dataset)} documents to swahili_oscar.txt")
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Using the latest cached version of the module from /root/.cache/huggingface/modules/datasets_modules/datasets/oscar/84838bd49d2295f62008383b05620571535451d84545037bb94d6f3501651df2 (last modified on Tue May 27 18:36:57 2025) since it couldn't be found locally at oscar, or remotely on the Hugging Face Hub.
# WARNING:datasets.load:Using the latest cached version of the module from /root/.cache/huggingface/modules/datasets_modules/datasets/oscar/84838bd49d2295f62008383b05620571535451d84545037bb94d6f3501651df2 (last modified on Tue May 27 18:36:57 2025) since it couldn't be found locally at oscar, or remotely on the Hugging Face Hub.
# Saved 24803 documents to swahili_oscar.txt
